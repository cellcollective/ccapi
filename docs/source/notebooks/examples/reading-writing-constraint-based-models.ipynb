# %%
import ccapi

config     = ccapi.Configuration()
config.url = "http://localhost:5000"

# %% [markdown]
# ### Reading and Writing Constraint-Based Models

# %% [markdown]
# [Cell Collective](https://cellcollective.org) supports reading models in SBML file format and exporting them into SBML.
#
# **ccapi** also ships with some test models.
#
# Let's try importing the [Dehalococcoides]() model.
#
# Begin by importing the ccapi module into your workspace.

# %%
import ccapi

# %% [markdown]
# Now, let’s try creating a client object in order to interact with services provided by [Cell Collective](https://cellcollective.org).

# %%
client = ccapi.Client()

# %% [markdown]
# Authenticate your client using a ***password flow type authentication*** scheme.
#
# **NOTE**: *Before you can authenticate using ccapi, you must first register an application of the appropriate type on [Cell Collective](https://cellcollective.org). If you do not require a user context, it is read only.*

# %%
client.auth(email = "test@cellcollective.org", password = "test")

# %% [markdown]
# You can also view user details of your authenticated client as follows:

# %%
user = client.me()
user
# Out:
# <User 1 at 0x07f378ebbc278 name='Test Test'>

# %% [markdown]
# #### SBML

# %% [markdown]
# The [Systems Biology Markup Language](http://sbml.org/Main_Page) is an XML-based standard format for distributing models. Reading SBML files is as easy as using the `read` function provided by the client object.
#
# **ccapi** comes shipped with test models for testing purposes.

# %%
model = ccapi.load_model("dehalococcoides", client = client)
model
# Out:
# 2020-01-17 12:09:59,654 | ERROR | Error recieved from the server: {"version":"2.7.0","id":"74b7c297ae4549fba87bc0e4c628ab7f","status":"error","code":500,"error":{"message":"Internal Server Error","errors":[{"message":{"executable":"python3","options":["-u","-m"],"script":"ccpy","args":["--action","read","--input","/app/cc/private/model/uploads/3e22337db4a862b8cc3e666ee12d7e46a32b9df5.sbml","--input-type","sbml","--model-type","metabolic"],"exitCode":1}}]}}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-26-da90a56ba06e> in <module>
# ----> 1 model = ccapi.load_model("dehalococcoides", client = client)
#       2 model
#
# ~/dev/ccapi/src/ccapi/__init__.py in load_model(name, *args, **kwargs)
#      21
#      22     client = kwargs.get("client", Client())
# ---> 23     model  = client.read(model["path"], type = model["type"])
#      24
#      25     return model
#
# ~/dev/ccapi/src/ccapi/api/client.py in read(self, filename, type, save)
#     521
#     522             response        = self.post("api/model/import", data = data,
# --> 523                 files = files)
#     524             content         = response.json()
#     525
#
# ~/dev/ccapi/src/ccapi/api/client.py in post(self, url, *args, **kwargs)
#     210             b'"First Name","Last Name","Email","Institution","Last Updated Date"\n'
#     211         """
# --> 212         response = self.request("POST", url, *args, **kwargs)
#     213         return response
#     214
#
# ~/dev/ccapi/src/ccapi/api/client.py in request(self, method, url, *args, **kwargs)
#     190                     logger.error("Error recieved from the server: %s" % response.text)
#     191
# --> 192                 response.raise_for_status()
#     193
#     194         return response
#
# ~/.venv/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://localhost:5000/api/model/import

# %% [markdown]
# Cell Collective has a native support for reading and writing in SBML qual.

# %%
metabolic = model.default_version
metabolic

# %% [markdown]
# #### Metabolites

# %%
metabolic.metabolites

# %% [markdown]
# #### Reactions

# %%
metabolic.reactions

# %% [markdown]
# #### Writing Models

# %% [markdown]
# Constraint-Based Models can be exported into the following formats.
#
# 1. SBML
# 2. CobraPy JSON Format
# 3. CobraPy YAML Format
# 4. MATLAB
#
# Exporting Constraint-Based Models can be done using **ccapi** using the `ConstraintBasedModel.write` function with the file type as the parameter. By default, `ConstraintBasedModel.write` exports a model into SBML format. A list of other formats can be found from `ccapi.constant.CONSTRAINT_BASED_MODEL_EXPORT_TYPE`. You can also pass the path to where it should be downloaded.

# %%
from ccapi._compat import iterkeys
list(iterkeys(ccapi.constant.CONSTRAINT_BASED_MODEL_EXPORT_TYPE))
# Out:
# ['sbml', 'json', 'yaml', 'matlab']

# %% [markdown]
# ##### SBML

# %% [markdown]
# Use the `sbml` type to download a `ConstraintBasedModel` into an SBML file format.

# %%
metabolic.write("_data/model/metabolic/%s/%s.sbml" % (metabolic.id, metabolic.version), type = "sbml")
# Out:
# 2020-01-17 12:07:32,888 | ERROR | Error recieved from the server: {"version":"2.7.0","id":"2873388d90b6486ea9614d01de7c4521","status":"error","code":500,"error":{"message":"Internal Server Error","errors":[{"message":{"executable":"python3","options":["-u","-m"],"script":"ccpy","args":["--action","read","--input","/tmp/tmp-269KLUpGRl0Moak","--input-type","json","--model-type","metabolic","--output-type","sbml"],"exitCode":1}}]}}
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-20-d7fb3441d451> in <module>
# ----> 1 metabolic.write("_data/model/metabolic/%s/%s.sbml" % (metabolic.id, metabolic.version), type = "sbml")
#
# ~/dev/ccapi/src/ccapi/model/model/metabolic/__init__.py in write(self, path, type, **kwargs)
#     141
#     142         response        = self.client.request("GET", "api/model/%s/export" % self.id,
# --> 143             params = params)
#     144
#     145         if not path:
#
# ~/dev/ccapi/src/ccapi/api/client.py in request(self, method, url, *args, **kwargs)
#     190                     logger.error("Error recieved from the server: %s" % response.text)
#     191
# --> 192                 response.raise_for_status()
#     193
#     194         return response
#
# ~/.venv/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://localhost:5000/api/model/1/export?version=1&type=sbml

# %% [markdown]
# ##### CobraPy JSON Format

# %% [markdown]
# Use the `json` type to download a `ConstraintBasedModel` into a CobraPy JSON Format.

# %%
metabolic.write("_data/model/metabolic/%s/%s.json" % (metabolic.id, metabolic.version), type = "json")

# %% [markdown]
# ##### CobraPy YAML Format

# %% [markdown]
# Use the `yaml` type to download a `ConstraintBasedModel` into a CobraPy YAML Format.

# %%
metabolic.write("_data/model/metabolic/%s/%s.yaml" % (metabolic.id, metabolic.version), type = "yaml")

# %% [markdown]
# ##### MATLAB

# %% [markdown]
# Use the `matlab` type to download a ConstraintBasedModel in a MATLAB Format.

# %%
# metabolic.write("_data/model/metabolic/%s/%s.mat" % (metabolic.id, metabolic.version), type = "matlab")

# %%
# Out:
# {'metabolites': [{'id': 1,
#    'name': 'M_10_Formyltetrahydrofolate_C20H21N7O7',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 2,
#    'name': 'M_1_2_Diacyl_sn_glycerol_3_phosphate_C5H5O8PR2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 3,
#    'name': 'M_1_2_Diacylglycerol_C5H6O5R2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 4,
#    'name': 'M_3_Phospho_D_glyceroyl_phosphate_C3H4O10P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 5,
#    'name': 'M_1_Aminopropan_2_ol_C3H10NO',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 6,
#    'name': 'M_D_1_Aminopropan_2_ol_O_phosphate_C3H9NO4P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 7,
#    'name': 'M_1_Pyrroline_5_carboxylate_C5H6NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 8,
#    'name': 'M_2_3_Dihydrodipicolinate_C7H5NO4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 9,
#    'name': 'M__R__2_3_Dihydroxy_3_methylbutanoate_C5H9O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 10,
#    'name': 'M__R__2_3_Dihydroxy_3_methylpentanoate_C6H11O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 11,
#    'name': 'M__S__2_5_Amino_1__5_phospho_D_ribosyl_imidazole_4_carboxamidosuccinate_C13H15N4O12P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 12,
#    'name': 'M_2_5_Diamino_6_hydroxy_4__5__phosphoribosylamino__pyrimidine_C9H14N5O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 13,
#    'name': 'M_LL_2_6_Diaminoheptanedioate_C7H14N2O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 14,
#    'name': 'M_meso_2_6_Diaminoheptanedioate_C7H14N2O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 15,
#    'name': 'M__S__2_Aceto_2_hydroxybutanoate_C6H9O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 16,
#    'name': 'M_2_Amino_4_hydroxy_6_hydroxymethyl_7_8_dihydropteridine_diphosphate_C7H8N5O8P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 17,
#    'name': 'M_2_Amino_4_hydroxy_6_hydroxymethyl_7_8_dihydropteridine_C7H9N5O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 18,
#    'name': 'M_But_2_enoyl_acyl_carrier_protein_C4H5OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 19,
#    'name': 'M_2_Carboxy_2_5_dihydro_5_oxofuran_2_acetate_C7H4O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 20,
#    'name': 'M_1__2_Carboxyphenylamino__1_deoxy_D_ribulose_5_phosphate_C12H13NO9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 21,
#    'name': 'M_2_Dehydro_3_deoxy_D_arabino_heptonate_7_phosphate_C7H10O10P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 22,
#    'name': 'M_2_Dehydropantoate_C6H9O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 23,
#    'name': 'M_2_Demethylmenaquinone_8_C50H70O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 24,
#    'name': 'M_2_Demethylmenaquinol_8_C50H72O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 25,
#    'name': 'M_2_Isopropylmaleate_C7H8O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 26,
#    'name': 'M_2__alpha_D_Mannosyl__3_phosphoglycerate_C9H17O12P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 27,
#    'name': 'M_2_Methyl_4_amino_5_hydroxymethylpyrimidine_diphosphate_C6H8N3O7P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 28,
#    'name': 'M_2_Methylbutanoyl_CoA_C26H40N7O17P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 29,
#    'name': 'M_cis_2_Methylaconitate_C7H5O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 30,
#    'name': 'M_2_C_methyl_D_erythritol_4_phosphate_C5H11O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 31,
#    'name': 'M_2_C_methyl_D_erythritol_2_4_cyclodiphosphate_C5H10O9P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 32,
#    'name': 'M__R__2_Oxo_3_methylpentanoate_C6H9O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 33,
#    'name': 'M_2_Oxobutanoate_C4H5O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 34,
#    'name': 'M_2_Octaprenyl_6_hydroxyphenol_C46H70O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 35,
#    'name': 'M_2_Octaprenyl_6_methoxy_1_4_benzoquinol_C47H72O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 36,
#    'name': 'M_2_Octaprenyl_3_methyl_5_hydroxy_6_methoxy_1_4_benzoquinol_C48H74O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 37,
#    'name': 'M_2_Octaprenyl3_methyl_6_methoxy__1_4_benzoquinol_C48H74O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 38,
#    'name': 'M_2_Octaprenyl_6_methoxyphenol_C47H72O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 39,
#    'name': 'M_2_phospho_4__cytidine_5__diphospho__2_C_methyl_D_erythritol_C14H22N3O17P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 40,
#    'name': 'M_D_Glycerate_2_phosphate_C3H4O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 41,
#    'name': 'M_trans_Dodec_2_enoyl_acyl_carrier_protein_C12H21OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 42,
#    'name': 'M_trans_Dec_2_enoyl_acyl_carrier_protein_C10H17OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 43,
#    'name': 'M_trans_Hex_2_enoyl_acp_C6H9OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 44,
#    'name': 'M_trans_Icos_2_enoyl_aceyl_carrier_protein_C20H37OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 45,
#    'name': 'M_trans_Octadec_2_enoyl_acyl_carrier_protein_C18H33OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 46,
#    'name': 'M_trans_Oct_2_enoyl_acp_C8H13OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 47,
#    'name': 'M_3__4_Hydroxyphenyl_pyruvate_C9H7O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 48,
#    'name': 'M__3S__3_6_Diaminohexanoate_C6H15N2O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 49,
#    'name': 'M_3_Carboxy_2_hydroxy_4_methylpentanoate_C7H10O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 50,
#    'name': 'M_3_Carboxy_3_hydroxy_4_methylpentanoate_C7H10O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 51,
#    'name': 'M_3_Carboxy_4_methyl_2_oxopentanoate_C7H8O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 52,
#    'name': 'M_3_Dehydroquinate_C7H9O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 53,
#    'name': 'M_3_Dehydroshikimate_C7H7O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 54,
#    'name': 'M_3_Fumarylpyruvate_C7H4O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 55,
#    'name': 'M__3R__3_Hydroxybutanoyl_acyl_carrier_protein_C4H7O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 56,
#    'name': 'M__R__3_Hydroxydodecanoyl_acyl_carrier_protein_C12H23O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 57,
#    'name': 'M__3R__3_Hydroxydecanoyl_acyl_carrier_protein_C10H19O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 58,
#    'name': 'M__R__3_Hydroxyhexanoyl_acp_C6H11O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 59,
#    'name': 'M__3R__3_Hydroxyicosanoyl_aceyl_carrier_protein_C20H39O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 60,
#    'name': 'M__R__3_Hydroxyoctanoyl_acyl_carrier_protein_C8H15O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 61,
#    'name': 'M__3R__3_Hydroxyoctadecanoyl_acyl_carrier_protein_C18H35O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 62,
#    'name': 'M__3R__3_Hydroxypalmitoyl_acyl_carrier_protein_C16H31O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 63,
#    'name': 'M__3R__3_Hydroxytetradecanoyl_acyl_carrier_protein_C14H27O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 64,
#    'name': 'M_C___3_Indolyl__glycerol_3_phosphate_C11H12NO6P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 65,
#    'name': 'M_3_Methyl_2_oxobutanoate_C5H7O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 66,
#    'name': 'M__S__3_Methyl_2_oxopentanoate_C6H9O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 67,
#    'name': 'M_3_Oxododecanoyl_acyl_carrier_protein_C12H21O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 68,
#    'name': 'M_3_Oxodecanoyl_acyl_carrier_protein_C10H17O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 69,
#    'name': 'M_3_Oxohexanoyl_acyl_carrier_protein_C6H9O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 70,
#    'name': 'M_3_Oxohexadecanoyl_acp_C16H29O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 71,
#    'name': 'M_3_Oxoicosanoyl_acyl_carrier_protein_C20H37O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 72,
#    'name': 'M_3_Oxooctanoyl_acyl_carrier_protein_C8H13O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 73,
#    'name': 'M_3_Oxooctadecanoyl_acp_C18H33O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 74,
#    'name': 'M_3_Oxotetradecanoyl_acyl_carrier_protein_C14H25O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 75,
#    'name': 'M_3_Phospho_D_glycerate_C3H4O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 76,
#    'name': 'M_3_Phosphohydroxypyruvate_C3H2O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 77,
#    'name': 'M_5_O__1_Carboxyvinyl__3_phosphoshikimate_C10H9O10P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 78,
#    'name': 'M_4_Aminobutanoate_C4H9NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 79,
#    'name': 'M_4_Aminobenzoate_C7H6NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 80,
#    'name': 'M_4_amino_4_deoxychorismate_C10H10NO5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 81,
#    'name': 'M_4_Amino_5_hydroxymethyl_2_methylpyrimidine_C6H9N3O',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 82,
#    'name': 'M_4_Amino_2_methyl_5_phosphomethylpyrimidine_C6H8N3O4P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 83,
#    'name': 'M_4__cytidine_5__diphospho__2_C_methyl_D_erythritol_C14H23N3O14P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 84,
#    'name': 'M_4_Hydroxy_benzyl_alcohol_C7H8O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 85,
#    'name': 'M_4_Hydroxyphenylacetyl_CoA_C29H38N7O18P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 86,
#    'name': 'M_4_Methyl_2_oxopentanoate_C6H9O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 87,
#    'name': 'M_4_Methyl_5__2_phosphoethyl__thiazole_C6H8NO4PS',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 88,
#    'name': 'M_4_Phospho_L_aspartate_C4H6NO7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 89,
#    'name': 'M_4_Phospho_D_erythronate_C4H6O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 90,
#    'name': 'M_D_4__Phosphopantothenate_C9H15NO8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 91,
#    'name': 'M_N___R__4_Phosphopantothenoyl__L_cysteine_C12H20N2O9PS',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 92,
#    'name': 'M_4__1_D_Ribitylamino__5_aminouracil_C9H16N4O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 93,
#    'name': 'M_5_amino_1__5_phospho_D_ribosyl_imidazole_4_carboxylate_C9H11N3O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 94,
#    'name': 'M_5_Amino_6__5__phosphoribitylamino_uracil_C9H15N4O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 95,
#    'name': 'M_5_Amino_6__5__phosphoribosylamino_uracil_C9H13N4O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 96,
#    'name': 'M_5_Methylthio_5_deoxy_D_ribose_1_phosphate_C6H11O7PS',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 97,
#    'name': 'M_5_Methylthio_5_deoxy_D_ribulose_1_phosphate_C6H11O7PS',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 98,
#    'name': 'M_5_Methylthioadenosine_C11H15N5O3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 99,
#    'name': 'M_5_Methyltetrahydrofolate_C20H24N7O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 100,
#    'name': 'M_5_Oxo_4_5_dihydrofuran_2_acetate_C6H5O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 101,
#    'name': 'M_N1__5_Phospho_alpha_D_ribosyl__5_6_dimethylbenzimidazole_C14H17N2O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 102,
#    'name': 'M_6_Pyruvoyl_5_6_7_8_tetrahydropterin_C9H11N5O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 103,
#    'name': 'M_8_Amino_7_oxononanoate_C9H17NO3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 104,
#    'name': 'M_acyl_carrier_protein_HX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 105,
#    'name': 'M_L_Saccharopine_C11H19N2O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 106,
#    'name': 'M_Acetyl_ACP_C2H3OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 107,
#    'name': 'M_Acetate_C2H3O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 108,
#    'name': 'M_Acetate_C2H3O2',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': -1},
#   {'id': 109,
#    'name': 'M_Acetaldehyde_C2H4O',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 110,
#    'name': 'M_Acetyl_CoA_C23H34N7O17P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 111,
#    'name': 'M_N_Acetyl_L_glutamyl_5_phosphate_C7H9NO8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 112,
#    'name': 'M_N_Acetyl_L_glutamate_5_semialdehyde_C7H10NO4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 113,
#    'name': 'M_N_Acetyl_D_glucosamine_1_phosphate_C8H14NO9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 114,
#    'name': 'M_N_Acetyl_L_glutamate_C7H9NO5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 115,
#    'name': 'M_O_Acetyl_L_homoserine_C6H11NO4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 116,
#    'name': 'M_N2_Acetyl_L_ornithine_C7H14N2O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 117,
#    'name': 'M_O_Acetyl_L_serine_C5H9NO4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 118,
#    'name': 'M_Acetoacetyl_ACP_C4H5O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 119,
#    'name': 'M_Adenosyl_cobinamide_C58H84CoN16O11',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 120,
#    'name': 'M_Adenosyl_cobinamide_phosphate_C58H83CoN16O14P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 121,
#    'name': 'M_Adenosyl_cobyrinate_diamide_C55H68CoN11O15',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 122,
#    'name': 'M_adenosyl_cobyric_acid_C55H76CoN15O11',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 123,
#    'name': 'M_Adenine_C5H5N5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 124,
#    'name': 'M_Adenosine_GDP_cobinamide_C68H95CoN21O21P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 125,
#    'name': 'M_Adenosine_C10H13N5O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 126,
#    'name': 'M_Adenosylcobalamin_C72H100CoN18O17P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 127,
#    'name': 'M_ADP_C10H12N5O10P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 128,
#    'name': 'M_ADPglucose_C16H23N5O15P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 129,
#    'name': 'M_ADPribose_C15H21N5O14P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 130,
#    'name': 'M_Agmatine_C5H16N4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 2},
#   {'id': 131,
#    'name': 'M_S_Adenosyl_L_homocysteine_C14H20N6O5S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 206,
#    'name': 'M_7_8_Diaminononanoate_C9H21N2O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 132,
#    'name': 'M_2_Amino_4_hydroxy_6__erythro_1_2_3_trihydroxypropyl_dihydropteridine_triphosphate_C9H12N5O13P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 133,
#    'name': 'M_5_Amino_1__5_Phospho_D_ribosyl_imidazole_4_carboxamide_C9H13N4O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 134,
#    'name': 'M_5_amino_1__5_phospho_D_ribosyl_imidazole_C8H12N3O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 135,
#    'name': 'M_2_Oxoglutarate_C5H4O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 136,
#    'name': 'M_beta_Alanine_C3H7NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 137,
#    'name': 'M_D_Alanine_C3H7NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 138,
#    'name': 'M_L_Alanine_C3H7NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 139,
#    'name': 'M_D_Alanyl_D_alanine_C6H12N2O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 140,
#    'name': 'M__S__2_Acetolactate_C5H7O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 141,
#    'name': 'M_L_Alanyl_tRNA_Ala__C3H7NO2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 142,
#    'name': 'M_S_Adenosyl_L_methionine_C15H23N6O5S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 143,
#    'name': 'M_S_Adenosyl_4_methylthio_2_oxobutanoate_C15H19N5O6S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 144,
#    'name': 'M_AMP_C10H12N5O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 145,
#    'name': 'M_Anthranilate_C7H6NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 146,
#    'name': 'M_Antimonite_Sb',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 3},
#   {'id': 147,
#    'name': 'M_Antimonite_Sb',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 3},
#   {'id': 148,
#    'name': 'M_apoprotein_acyl_carrier_protein_RHO',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 149,
#    'name': 'M_Adenosine_5__phosphosulfate_C10H12N5O10PS',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 150,
#    'name': 'M_L_Arginine_C6H15N4O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 151,
#    'name': 'M_N_omega___L_Arginino_succinate_C10H17N4O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 152,
#    'name': 'M_L_Arginyl_tRNA_Arg__C6H15N4O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 2},
#   {'id': 153,
#    'name': 'M_Arsenate_AsHO4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 154,
#    'name': 'M_Arsenate_AsHO4',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': -2},
#   {'id': 155,
#    'name': 'M_arsenite_AsH3O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 156,
#    'name': 'M_arsenite_AsH3O3',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 157,
#    'name': 'M_L_Asparagine_C4H8N2O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 158,
#    'name': 'M_L_Aspartate_C4H6NO4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 159,
#    'name': 'M_L_Aspartate_4_semialdehyde_C4H7NO3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 160,
#    'name': 'M_L_Aspartyl_tRNA_Asp__C4H6NO4X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 161,
#    'name': 'M_ATP_C10H12N5O13P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 162,
#    'name': 'M_Biotinyl_5__AMP_C20H27N7O9PS',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 163,
#    'name': 'M_Biotin_C10H15N2O3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 164,
#    'name': 'M_Butyryl_acyl_carrier_protein_C4H7OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 165,
#    'name': 'M_cAMP_C10H11N5O6P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 166,
#    'name': 'M_N_Carbamoyl_L_aspartate_C5H6N2O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 167,
#    'name': 'M_Cobinamide_C48H72CoN11O8',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 168,
#    'name': 'M_Cob_I_alamin_C62H88CoN13O14P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 169,
#    'name': 'M_Cob_I_alamin_C62H88CoN13O14P',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': -1},
#   {'id': 170,
#    'name': 'M_Carbamoyl_phosphate_CH2NO5P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 171,
#    'name': 'M_Citraconate_C5H6O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 172,
#    'name': 'M_Cardiolipin_C13H16O17P2R4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 173,
#    'name': 'M_CDP_C9H12N3O11P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 174,
#    'name': 'M_CDPdiacylglycerol_C14H17N3O15P2R2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 175,
#    'name': 'M_Chorismate_C10H8O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 176,
#    'name': 'M_Citrate_C6H5O7',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 177,
#    'name': 'M_Citrate_C6H5O7',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': -3},
#   {'id': 178,
#    'name': 'M_L_Citrulline_C6H13N3O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 179,
#    'name': 'M__3R__citramalate_C5H8O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 180,
#    'name': 'M_Chloride_Cl',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': -1},
#   {'id': 181,
#    'name': 'M_CMP_C9H12N3O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 182,
#    'name': 'M_Cob_I_yrinate_a_c_diamide_C45H56CoN6O12',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -5},
#   {'id': 183,
#    'name': 'M_CO2_CO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 184,
#    'name': 'M_CO2_CO2',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 185,
#    'name': 'M_Cob_II_yrinate_a_c_diamide_C45H56CoN6O12',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 186,
#    'name': 'M_Carbon_monoxide_CO',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 187,
#    'name': 'M_Coenzyme_A_C21H32N7O16P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 188,
#    'name': 'M_Co2_Co',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 2},
#   {'id': 189,
#    'name': 'M_Co2_Co',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 2},
#   {'id': 190,
#    'name': 'M_Cobamide_coenzyme_C72H100CoN18O17P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 191,
#    'name': 'M_Cobyrinate_C45H52CoN4O14',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -6},
#   {'id': 192,
#    'name': 'M_Cobalt_dihydro_precorrin_6_C44H47CoN4O16',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -7},
#   {'id': 193,
#    'name': 'M_cobalt_precorrin_3_C43H39N4O16Co',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -8},
#   {'id': 194,
#    'name': 'M_cobalt_precorrin_4_C44H43CoN4O16',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -6},
#   {'id': 195,
#    'name': 'M_Cobalt_precorrin_8_C45H52CoN4O14',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -6},
#   {'id': 196,
#    'name': 'M_Coproporphyrinogen_III_C36H40N4O8',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 197,
#    'name': 'M_CTP_C9H12N3O14P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 198,
#    'name': 'M_Cu2_Cu',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 2},
#   {'id': 199,
#    'name': 'M_Cu2_Cu',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 2},
#   {'id': 200,
#    'name': 'M_L_Cysteine_C3H7NO2S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 201,
#    'name': 'M_Cysteamine_C2H8NS',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 202,
#    'name': 'M_L_Cysteinyl_tRNA_Cys__C3H7NO2SX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 203,
#    'name': 'M_5__Deoxyadenosine_C10H13N5O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 204,
#    'name': 'M_dADP_C10H12N5O9P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 205,
#    'name': 'M_dAMP_C10H12N5O6P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 207,
#    'name': 'M_dATP_C10H12N5O12P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 208,
#    'name': 'M_3_4_dihydroxy_2_butanone_4_phosphate_C4H7O6P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 209,
#    'name': 'M_N6__1_2_Dicarboxyethyl__AMP_C14H14N5O11P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 210,
#    'name': 'M_1_4_Dichlorobenzene__para_Dichlorobenzene__C6H4Cl2',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 211,
#    'name': 'M_dCDP_C9H12N3O10P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 212,
#    'name': 'M_dCMP_C9H12N3O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 213,
#    'name': 'M_dCTP_C9H12N3O13P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 214,
#    'name': 'M_Dodecanoyl_ACP__n_C120ACP__C12H23OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 215,
#    'name': 'M_dodecanoate__C120__C12H23O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 216,
#    'name': 'M_Dodecanoyl_CoA__n_C120CoA__C33H54N7O17P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 217,
#    'name': 'M_D_erythro_3_Methylmalate_C5H8O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 218,
#    'name': 'M_Decanoyl_acyl_carrier_protein_C10H19OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 219,
#    'name': 'M_all_trans_Decaprenyl_diphosphate_C50H81O7P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 220,
#    'name': 'M_dGDP_C10H12N5O10P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 221,
#    'name': 'M_dGMP_C10H12N5O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 222,
#    'name': 'M_Deoxyguanosine_C10H13N5O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 223,
#    'name': 'M_dGTP_C10H12N5O13P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 224,
#    'name': 'M_Dihydroxyacetone_phosphate_C3H5O6P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 225,
#    'name': 'M_7_8_Dihydrofolate_C19H19N7O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 226,
#    'name': 'M_Dihydrolipolprotein_H2S2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 227,
#    'name': 'M_1_4_Dihydroxy_2_naphthoate_C11H7O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 228,
#    'name': 'M_2_Amino_4_hydroxy_6__D_erythro_1_2_3_trihydroxypropyl__7_8_dihydropteridine_C9H13N5O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 229,
#    'name': 'M__S__Dihydroorotate_C5H5N2O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 230,
#    'name': 'M_Dihydroneopterin_monophosphate_C9H12N5O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 231,
#    'name': 'M_Dihydropteroate_C14H13N6O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 232,
#    'name': 'M_dIMP_C10H12N4O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 233,
#    'name': 'M_dITP_C10H11N4O13P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 234,
#    'name': 'M_5_6_Dimethylbenzimidazole_C9H10N2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 235,
#    'name': 'M_6_7_Dimethyl_8__1_D_ribityl_lumazine_C13H18N4O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 236,
#    'name': 'M_Dimethylallyl_diphosphate_C5H9O7P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 237,
#    'name': 'M_Deamino_NAD_C21H24N6O15P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 238,
#    'name': 'M_Dephospho_CoA_C21H33N7O13P2S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 239,
#    'name': 'M_Dethiobiotin_C10H17N2O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 240,
#    'name': 'M_dTDP_C10H13N2O11P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 241,
#    'name': 'M_dTDPglucose_C16H24N2O16P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 242,
#    'name': 'M_dTMP_C10H13N2O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 243,
#    'name': 'M_dTTP_C10H13N2O14P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 244,
#    'name': 'M_dUDP_C9H11N2O11P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 245,
#    'name': 'M_dUMP_C9H11N2O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 246,
#    'name': 'M_dUTP_C9H11N2O14P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 247,
#    'name': 'M_1_deoxy_D_xylulose_5_phosphate_C5H9O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 248,
#    'name': 'M_D_Erythrose_4_phosphate_C4H7O7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 249,
#    'name': 'M_D_erythro_1__Imidazol_4_yl_glycerol_3_phosphate_C6H9N2O6P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 250,
#    'name': 'M_Ethylene_C2H4',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 251,
#    'name': 'M_Ethanol_C2H6O',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 252,
#    'name': 'M_D_Fructose_1_phosphate_C6H11O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 253,
#    'name': 'M_D_Fructose_6_phosphate_C6H11O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 254,
#    'name': 'M_Fatty_acid__Iso_C170__C17H33O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 255,
#    'name': 'M_Iso_C170_CoA_C38H64N7O17P3S1',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 256,
#    'name': 'M_FAD_C27H31N9O15P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 257,
#    'name': 'M_FADH2_C27H33N9O15P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 258,
#    'name': 'M_L_Fuculose_1_phosphate_C6H11O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 259,
#    'name': 'M_ferredoxin__oxidized__24Fe_4S_Fe8S8X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 3},
#   {'id': 260,
#    'name': 'M_D_Fructose_1_6_bisphosphate_C6H10O12P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 261,
#    'name': 'M_ferredoxin__reduced__24Fe_4S_Fe8S8X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 2},
#   {'id': 262,
#    'name': 'M_Fe2_Fe',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 2},
#   {'id': 263,
#    'name': 'M_Fe2_Fe',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 2},
#   {'id': 264,
#    'name': 'M_N2_Formyl_N1__5_phospho_D_ribosyl_glycinamide_C8H13N2O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 265,
#    'name': 'M_N_Formyl_L_methionine_C6H10NO3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 266,
#    'name': 'M_N_Formylmethionyl_tRNA_C6H11NO3SX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 267,
#    'name': 'M_flavin_mononucleotide_C17H19N4O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 268,
#    'name': 'M_Folate_C19H18N7O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 269,
#    'name': 'M_Formate_CH1O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 270,
#    'name': 'M_2__Formamido__N1__5_phospho_D_ribosyl_acetamidine_C8H14N3O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 271,
#    'name': 'M_5_Formamido_1__5_phospho_D_ribosyl_imidazole_4_carboxamide_C10H13N4O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 272,
#    'name': 'M_Farnesyl_diphosphate_C15H25O7P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 273,
#    'name': 'M_D_Fructose_C6H12O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 274,
#    'name': 'M_Fumarate_C4H2O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 275,
#    'name': 'M_D_Glucose_1_phosphate_C6H11O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 276,
#    'name': 'M_Glyceraldehyde_3_phosphate_C3H5O6P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 277,
#    'name': 'M_D_Glucose_6_phosphate_C6H11O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 278,
#    'name': 'M_D_Glucosamine_1_phosphate_C6H13NO8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 279,
#    'name': 'M_D_Glucosamine_6_phosphate_C6H13NO8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 280,
#    'name': 'M_N1__5_Phospho_D_ribosyl_glycinamide_C7H14N2O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 281,
#    'name': 'M_Glycolaldehyde_C2H4O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 282,
#    'name': 'M_GDP_C10H12N5O11P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 283,
#    'name': 'M_GDP_D_mannose_C16H23N5O16P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 284,
#    'name': 'M_Guanosine_3__diphosphate_5__triphosphate_C10H11N5O20P5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -7},
#   {'id': 285,
#    'name': 'M_Geranylgeranyl_diphosphate_C20H33O7P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 286,
#    'name': 'M_D_Glucose_C6H12O6',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 287,
#    'name': 'M_L_Glutamine_C5H10N2O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 288,
#    'name': 'M_L_Glutamine_C5H10N2O3',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 289,
#    'name': 'M_L_Glutaminyl_tRNA_Gln__C5H10N2O3X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 290,
#    'name': 'M_L_Glutamate_5_phosphate_C5H8NO7P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 291,
#    'name': 'M_L_Glutamate_5_semialdehyde_C5H9NO3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 292,
#    'name': 'M_L_Glutamate_C5H8NO4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 293,
#    'name': 'M_L_Glutamyl_tRNA_Glu__C5H8NO4X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 294,
#    'name': 'M_Glycine_C2H5NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 295,
#    'name': 'M_D_Glyceraldehyde_C3H6O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 296,
#    'name': 'M_Glycine_betaine_C5H11NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 297,
#    'name': 'M_Glycine_betaine_C5H11NO2',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 298,
#    'name': 'M_sn_Glycerol_3_phosphate_C3H7O6P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 299,
#    'name': 'M__R__Glycerate_C3H5O4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 300,
#    'name': 'M_Glycerol_C3H8O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 301,
#    'name': 'M_glycogen_C6H10O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 302,
#    'name': 'M_Glycyl_tRNA_Gly__C2H5NO2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 303,
#    'name': 'M_D_Glycero_D_manno_heptose_7_phosphate_C7H13O10P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 304,
#    'name': 'M_GMP_C10H12N5O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 305,
#    'name': 'M_Geranyl_diphosphate_C10H17O7P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 306,
#    'name': 'M_Guanosine_C10H13N5O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 307,
#    'name': 'M_Reduced_glutathione_C10H16N3O6S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 308,
#    'name': 'M_GTP_C10H12N5O14P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 309,
#    'name': 'M_Guanine_C5H5N5O',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 310,
#    'name': 'M_H2_H2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 311,
#    'name': 'M_H2_H2',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 312,
#    'name': 'M_1_hydroxy_2_methyl_2__E__butenyl_4_diphosphate_C5H9O8P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 313,
#    'name': 'M_Hydrogen_peroxide_H2O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 314,
#    'name': 'M_H2O_H2O',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 315,
#    'name': 'M_H2O_H2O',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 316,
#    'name': 'M_Hydrogen_sulfide_HS',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 317,
#    'name': 'M_H_H',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 318,
#    'name': 'M_H_H',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 1},
#   {'id': 319,
#    'name': 'M_Hexachlorobenzene_C6Cl6',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 320,
#    'name': 'M_Homocitrate_C7H7O7',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 321,
#    'name': 'M_Bicarbonate_CHO3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 322,
#    'name': 'M_L_Homocysteine_C4H9NO2S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 323,
#    'name': 'M_Hexadecanoate__n_C160__C16H31O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 324,
#    'name': 'M_Hexadecenoyl_ACP__n_C161ACP__C16H29OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 325,
#    'name': 'M_all_trans_Heptaprenyl_diphosphate_C35H57O7P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 326,
#    'name': 'M_Hexanoyl_acyl_carrier_protein_C6H11OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 327,
#    'name': 'M_all_trans_Hexaprenyl_diphosphate_C30H49O7P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 328,
#    'name': 'M_Mercury__uncharged__Hg',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 329,
#    'name': 'M_Mercury__charged_2__Hg',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 2},
#   {'id': 330,
#    'name': 'M_L_Histidine_C6H9N3O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 331,
#    'name': 'M_L_Histidinol_phosphate_C6H11N3O4P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 332,
#    'name': 'M_L_Histidinol_C6H12N3O',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 333,
#    'name': 'M_L_Histidyl_tRNA_His__C6H9N3O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 334,
#    'name': 'M_Hydroxymethylbilane_C40H38N4O17',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -8},
#   {'id': 335,
#    'name': 'M_L_Homoserine_C4H9NO3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 336,
#    'name': 'M_Homospermidine_C8H24N3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 3},
#   {'id': 337,
#    'name': 'M_Hypoxanthine_C5H4N4O',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 338,
#    'name': 'M_Iminoaspartate_C4H3NO4',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 339,
#    'name': 'M_Isobutyryl_CoA_C25H38N7O17P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 340,
#    'name': 'M_Isocitrate_C6H5O7',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 341,
#    'name': 'M_Icosanoyl_ACP__n_C200ACP__C20H39OX',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 342,
#    'name': 'M_Icosanoate__n_C200__C20H39O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 343,
#    'name': 'M_Icosanoyl_CoA__n_C200_CoA__C41H70N7O17P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 344,
#    'name': 'M_IDP_C10H11N4O11P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 345,
#    'name': 'M_L_Isoleucine_C6H13NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 346,
#    'name': 'M_L_Isoleucine_C6H13NO2',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 347,
#    'name': 'M_L_Isoleucyl_tRNA_Ile__C6H13NO2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 348,
#    'name': 'M_3__Imidazol_4_yl__2_oxopropyl_phosphate_C6H8N2O5P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 349,
#    'name': 'M_IMP_C10H11N4O8P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 350,
#    'name': 'M_S_2__indol_3_yl_acetyl_CoA_C31H39N8O17P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 351,
#    'name': 'M_Indolepyruvate_C11H8NO3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 352,
#    'name': 'M_Isopentenyl_diphosphate_C5H9O7P2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -3},
#   {'id': 353,
#    'name': 'M_ITP_C10H11N4O14P3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 354,
#    'name': 'M_Isovaleryl_CoA_C26H40N7O17P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -4},
#   {'id': 355,
#    'name': 'M_K_K',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 356,
#    'name': 'M_K_K',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 1},
#   {'id': 357,
#    'name': 'M_D_Lactate_C3H5O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 358,
#    'name': 'M_L_Lactate_C3H5O3',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 359,
#    'name': 'M_L_Lactaldehyde_C3H6O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 360,
#    'name': 'M_L_Leucine_C6H13NO2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 361,
#    'name': 'M_L_Leucine_C6H13NO2',
#    'compartment': 'Extra_organism',
#    'formula': None,
#    'charge': 0},
#   {'id': 362,
#    'name': 'M_L_Leucyl_tRNA_Leu__C6H13NO2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 363,
#    'name': 'M__R__S_Lactoylglutathione_C13H20N3O8S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 364,
#    'name': 'M_Lipid_A_Disaccharide_C68H127N2O20P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 365,
#    'name': 'M_2_3_Bis_3_hydroxytetradecanoyl__beta_D_glucosaminyl_1_phosphate_C34H64NO12P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 366,
#    'name': 'M_Lipoylprotein_S2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 0},
#   {'id': 367,
#    'name': 'M_L_Lysine_C6H15N2O2',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 1},
#   {'id': 368,
#    'name': 'M_L_Lysine_tRNA__Lys__C6H15N2O2X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': 2},
#   {'id': 369,
#    'name': 'M_Malonyl_acyl_carrier_protein_C3H2O3X',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -1},
#   {'id': 370,
#    'name': 'M_L_Malate_C4H4O5',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 371,
#    'name': 'M_Malonyl_CoA_C24H33N7O19P3S',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -5},
#   {'id': 372,
#    'name': 'M_D_Mannose_1_phosphate_C6H11O9P',
#    'compartment': 'Cytosol',
#    'formula': None,
#    'charge': -2},
#   {'id': 373,
#    'name': 'M_D_Mannose_6_phosphate_C6H11O9P',
#    'compartment': 'Cytosol',
# ...
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 482,
#    'name': 'R_phosphate_transport_via_ABC_system',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 483,
#    'name': 'R_phosphate_transport_inout_via_proton_symporter',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 484,
#    'name': 'R_phosphomannomutase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 485,
#    'name': 'R_pyrimidine_phosphatase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 486,
#    'name': 'R_phosphomethylpyrimidine_kinase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 487,
#    'name': 'R_Hydrolase_Class___RXN_R02973_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 488,
#    'name': 'R_pantothenate_kinase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 489,
#    'name': 'R_pyruvate_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 490,
#    'name': 'R_inorganic_diphosphatase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 491,
#    'name': 'R_inorganic_diphosphatase__one_proton_translocation_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 492,
#    'name': 'R_phosphopantothenoylcysteine_decarboxylase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 493,
#    'name': 'R_Propionyl_CoA_carboxylase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 494,
#    'name': 'R_pyruvate_phosphate_dikinase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 495,
#    'name': 'R_phosphopantothenate_cysteine_ligase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 496,
#    'name': 'R_prephenate_dehydrogenase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 497,
#    'name': 'R_prephenate_dehydratase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 498,
#    'name': 'R_phosphoenolpyruvate_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 499,
#    'name': 'R_trans_pentaprenyltranstransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 500,
#    'name': 'R_phosphoribosylglycinamide_synthetase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 501,
#    'name': 'R_phosphoribosylanthranilate_isomerase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 502,
#    'name': 'R_phosphoribosylaminoimidazole_synthetase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 503,
#    'name': 'R_phosphoribosyl_AMP_cyclohydrolase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 504,
#    'name': 'R_phosphoribosylaminoimidazolesuccinocarboxamide_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 505,
#    'name': 'R_phosphoribosyl_ATP_pyrophosphatase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 506,
#    'name': 'R_phosphoribosylformylglycinamidine_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 507,
#    'name': 'R_1__5_phosphoribosyl__5__5_phosphoribosylamino_methylideneamino_imidazole_4_carboxamide_isomerase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 508,
#    'name': 'R_Prolyl_tRNA_synthetase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 509,
#    'name': 'R_L_proline_transport_inout_via_proton_symport',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 510,
#    'name': 'R_phosphoribosylpyrophosphate_synthetase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 511,
#    'name': 'R_3_phosphoshikimate_1_carboxyvinyltransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 512,
#    'name': 'R_3_phosphoserine_aminotransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 513,
#    'name': 'R_phosphoserine_phosphatase__L_serine_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 514,
#    'name': 'R_pseudouridylate_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 515,
#    'name': 'R_6_pyruvoyltetrahydropterin_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 516,
#    'name': 'R_pantetheine_phosphate_adenylyltransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 517,
#    'name': 'R_pyridoxamine_phosphate_oxidase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 518,
#    'name': 'R_pyruvate_kinase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 519,
#    'name': 'R_quinolinate_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 520,
#    'name': 'R_riboflavin_kinase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 521,
#    'name': 'R_riboflavin_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 522,
#    'name': 'R_riboflavin_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 523,
#    'name': 'R_ribokinase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 524,
#    'name': 'R_alpha_ribazole_5_phosphatase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 525,
#    'name': 'R_ribonucleoside_diphosphate_reductase__ADP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 526,
#    'name': 'R_ribonucleoside_diphosphate_reductase__GDP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 527,
#    'name': 'R_ribonucleoside_diphosphate_reductase__CDP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 528,
#    'name': 'R_ribonucleoside_diphosphate_reductase__UDP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 529,
#    'name': 'R_ribonucleoside_triphosphate_reductase__ATP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 530,
#    'name': 'R_ribonucleoside_triphosphate_reductase__GTP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 531,
#    'name': 'R_ribonucleoside_triphosphate_reductase__CTP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 532,
#    'name': 'R_ribonucleoside_triphosphate_reductase__UTP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 533,
#    'name': 'R_ribulose_5_phosphate_3_epimerase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 534,
#    'name': 'R_ribose_5_phosphate_isomerase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 535,
#    'name': 'R_sedoheptulose_7_phosphate_isomerase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 536,
#    'name': 'R_saccharopine_dehydrogenase__NAD__L_lysine_forming_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 537,
#    'name': 'R_sulfate_adenylyltransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 538,
#    'name': 'R_succinyl_diaminopimelate_desuccinylase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 539,
#    'name': 'R_succinyldiaminopimelate_transaminase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 540,
#    'name': 'R_serine_O_acetyltransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 541,
#    'name': 'R_L_serine_deaminase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 542,
#    'name': 'R_Seryl_tRNA_synthetase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 543,
#    'name': 'R_shikimate_dehdrogenase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 544,
#    'name': 'R_shikimate_kinase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 545,
#    'name': 'R_superoxide_dismutase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 546,
#    'name': 'R_succinyl_CoA_synthetase__ADP_forming_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 547,
#    'name': 'R_sulfite_reductase__NADPH2_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 548,
#    'name': 'R_sulfate_transport_via_ABC_system',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 549,
#    'name': 'R_transaldolase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 550,
#    'name': 'R_Tetradecanoyl_acyl_carrier_proteinmalonyl_CoA__C_acyltransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 551,
#    'name': 'R_Tagatose_bisphosphate_aldolase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 552,
#    'name': 'R_tetrahydropicolinate_succinylase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 553,
#    'name': 'R_threonine_aldolase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 554,
#    'name': 'R_L_threonine_deaminase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 555,
#    'name': 'R_L_allo_threonine_aldolase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 556,
#    'name': 'R_threonine_phosphate_decarboxylase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 557,
#    'name': 'R_threonine_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 558,
#    'name': 'R_Threonyl_tRNA_synthetase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 559,
#    'name': 'R_thiazole_phosphate_synthesis',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 560,
#    'name': 'R_transketolase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 561,
#    'name': 'R_transketolase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 562,
#    'name': 'R_thymidine_kinase__ATPthymidine_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 563,
#    'name': 'R_thymidylate_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 564,
#    'name': 'R_thiamine_phosphate_kinase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 565,
#    'name': 'R_thiamine_phosphate_diphosphorylase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 566,
#    'name': 'R_triose_phosphate_isomerase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 567,
#    'name': 'R_thioredoxin_reductase__NADPH_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 568,
#    'name': 'R_tryptophan_synthase__indoleglycerol_phosphate_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 569,
#    'name': 'R_Tryptophanyl_tRNA_synthetase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 570,
#    'name': 'R_thiosulfate_transport_via_ABC_system',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 571,
#    'name': 'R_tyrosine_transaminase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 572,
#    'name': 'R_Tyrosyl_tRNA_synthetase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 573,
#    'name': 'R_UDP_N_acetylglucosamine_1_carboxyvinyltransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 574,
#    'name': 'R_UDP_N_acetylglucosamine_diphosphorylase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 575,
#    'name': 'R_UDP_N_acetylenolpyruvoylglucosamine_reductase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 576,
#    'name': 'R_undecaprenyl_diphosphate_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 577,
#    'name': 'R_UDPglucose_4_epimerase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 578,
#    'name': 'R_UMP_kinase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 579,
#    'name': 'R_uroporphyrinogen_methyltransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 580,
#    'name': 'R_uroporphyrinogen_III_synthase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 581,
#    'name': 'R_uracil_phosphoribosyltransferase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 582,
#    'name': 'R_uridylate_kinase__UMP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 583,
#    'name': 'R_uridylate_kinase__dUMP_',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 584,
#    'name': 'R_valine_transaminase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 585,
#    'name': 'R_Valyl_tRNA_synthetase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 586,
#    'name': 'R_L_valine_transport_via_ABC_system',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 587,
#    'name': 'R_Lumped_reaction_for_degradation_of_glycoaldehyde',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 588,
#    'name': 'R_XTP_pyrophosphatase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 589,
#    'name': 'R_xylose_isomerase',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'},
#   {'id': 590,
#    'name': 'R_zinc_transport_in_via_ABC_system',
#    'subsystem': None,
#    'lower_bound': '-Infinity',
#    'upper_bound': 'Infinity'}],
#  'type': 'metabolic'}
