# %% [markdown]
# ### Building a Constraint-Based Model

# %% [markdown]
# This simple example demonstrates how to create a model, create a reaction, and then add the reaction to the model.

# %%
import cc

# %%
# create a boolean model
constraint = cc.ConstraintBasedModel("STM_1.0")
